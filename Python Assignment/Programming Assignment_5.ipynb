# %% [markdown]
# ## Python Basic Programming Assignment - 5
# --------------

# %% [markdown]
# ### 1. Write a Python Program to Find LCM?

# %%
def compute_lcm(x, y):
  if x > y:
    greater = x
  else:
    greater = y

  while(True):
    if((greater % x == 0) and (greater % y == 0)):
      lcm = greater
      break
    greater += 1

  return lcm

# %%
print("The LCM is ", compute_lcm(24,54))
# Out:
# The LCM is  216

# %% [markdown]
# ### 2. Write a Python Program to Find HCF?

# %%
num1 = int(input("Enter a Number:"))
num2 = int(input("Enter a Number:"))

for i in range(1, min(num1, num2)):
  if num1 % i == 0 and num2 % i == 0:
      hcf = i
print("HCF of", num1, "and", num2 ,"is", hcf)
# Out:
# Enter a Number:21
# Enter a Number:12
# HCF of 21 and 12 is 3

# %% [markdown]
# ### 3. Write a Python Program to Convert Decimal to Binary, Octal and Hexadecimal?

# %%
num = int(input("Enter a Number:"))

print("The Decima value of", num, "is:")
print(bin(num),"in binary")
print(oct(num),"in octal")
print(hex(num),"in hexadecimal")
# Out:
# Enter a Number:12
# The Decima value of 12 is:
# 0b1100 in binary
# 0o14 in octal
# 0xc in hexadecimal

# %% [markdown]
# ### 4. Write a Python Program To Find ASCII value of a character?

# %%
word = 'H'
print("The ASCII value of a character " + word + " is", ord(word))
# Out:
# The ASCII value of a character H is 72

# %% [markdown]
# ### 5. Write a Python Program to Make a Simple Calculator with 4 basic mathematical operations?

# %%
def mathematical_expression():
  print("Welcome to the Simple Calculator!")
  num1= float(input("Enter the first number: "))
  num2 = float(input("Enter the secons number: "))
  operation= input("Enter the operstion (+, -, *, /):")

  if operation == "+":
    result = num1 + num2
    print(f"{num1} + {num2} = {result}")
  elif operation == "-":
    result = num1 - num2
    print(f"{num1} - {num2} ={result}") 
  elif operation ==  "*":
    result = num1 * num2 
    print(f"{num1} * {num2} = {result}")
  elif operation == "/":
    result = num1 / num2
    print(f"{num1} / {num2} = {result}")
  else:
    print("Invalid Parameters")

mathematical_expression()
# Out:
# Welcome to the Simple Calculator!
# Enter the first number: 12
# Enter the secons number: 25
# Enter the operstion (+, -, *, /):+
# 12.0 + 25.0 = 37.0
