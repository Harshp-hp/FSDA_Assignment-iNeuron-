# %% [markdown]
# ## Programming Assignment_3
# ----------------

# %% [markdown]
# ### 1. Write a Python Program to Check if a Number is Positive, Negative or Zero?

# %%
num = float(input("Enter a Number: "))
if num > 0:
  print("Entered Number is Positive Number")
elif num == 0:
  print("Entered Number is Zero")
else:
  print("Entered Number is Negative Number")
# Out:
# Enter a Number: -1
# Entered Number is Negative Number

# %% [markdown]
# ### 2. Write a Python Program to Check if a Number is Odd or Even?

# %%
num = float(input("Enter a Number to Check or odd:"))
if num % 2 == 0:
  print("Entered Number is Even")
else:
  print("Entered Number is odd")
# Out:
# Enter a Number to Check or odd:23
# Entered Number is odd

# %% [markdown]
# ### 3. Write a Python Program to Check Leap Year?

# %%
Year = int(input("Enter a Year: "))

if(Year % 400 == 0) and (Year % 100 == 0):
  print("{0} is a leap year".format(Year))
elif(Year % 4 == 0)  and (Year % 100 != 0):
  print("{0} i not a leap year".format(Year))
else:
  print("{0} is not a leap year".format(Year))
# Out:
# Enter a Year: 2022
# 2022 is not a leap year

# %% [markdown]
# ### 4. Write a Python Program to Check Prime Number?

# %%
num= int(input("Enter a Number:"))

## program to check the prime number

if num > 1:
  for i in range(2, num):
    if(num % i) == 0:
      print(num, "is not a prime number")
      break
  else: 
      print(num, " is a prime number")  
else:
  print(num, "is not a prime number")
# Out:
# Enter a Number:92
# 92 is not a prime number

# %% [markdown]
# ### 5. Write a Python Program to Print all Prime Numbers in an Interval of 1-10000?

# %%
L_Value = int(input("Enter a Lower Number :"))
U_Value = int(input("Enter a Upper Number:"))

## program to check the prime number
for number in range(L_Value, U_Value + 1 ):
  if number > 1:
    for i in range(2, number):
      if(number % i) == 0:
        print(number, "is not a prime number")
        break
    else: 
        print(number, " is a prime number")  
  else:
    print(number, "is not a prime number")
# Out:
# Streaming output truncated to the last 5000 lines.
# 5001 is not a prime number
# 5002 is not a prime number
# 5003  is a prime number
# 5004 is not a prime number
# 5005 is not a prime number
# 5006 is not a prime number
# 5007 is not a prime number
# 5008 is not a prime number
# 5009  is a prime number
# 5010 is not a prime number
# 5011  is a prime number
# 5012 is not a prime number
# 5013 is not a prime number
# 5014 is not a prime number
# 5015 is not a prime number
# 5016 is not a prime number
# 5017 is not a prime number
# 5018 is not a prime number
# 5019 is not a prime number
# 5020 is not a prime number
# 5021  is a prime number
# 5022 is not a prime number
# 5023  is a prime number
# 5024 is not a prime number
# 5025 is not a prime number
# 5026 is not a prime number
# 5027 is not a prime number
# 5028 is not a prime number
# 5029 is not a prime number
# 5030 is not a prime number
# 5031 is not a prime number
# 5032 is not a prime number
# 5033 is not a prime number
# ...
